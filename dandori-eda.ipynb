# %%
import pandas as pd
df = pd.read_pickle("all-pdfs/courses.pkl")

# %%
df.head()
# Out:
#                                            file_name    class_id  \
# 0   class_001_The_Art_of_Wondrous_Waffle_Weaving.pdf  CLASS_4033
# 1     class_008_Magical_Woolly_Mammoth_Sculpting.pdf  CLASS_8046
# 2      class_015_the_magical_marmalade_adventure.pdf  CLASS_0425
# 3  class_023_the_art_of_whimsical_waffle_weaving.pdf  CLASS_1041
#
#                                  title                instructor  \
# 0   The Art of Wondrous Waffle Weaving             Chef Waffleby
# 1     Magical Woolly Mammoth Sculpting  Professor Woolly Mammoth
# 2      The Magical Marmalade Adventure            Chef Marmalock
# 3  The Art of Whimsical Waffle Weaving    Chef Waffleton Crumble
#
#          location    course_type  cost_gbp  \
# 0       Harrogate  Culinary Arts      75.0
# 1  Northumberland     Fiber Arts      75.0
# 2       Inverness  Culinary Arts      55.0
# 3            York  Culinary Arts      75.0
#
#                                  learning_objectives  \
# ...

# %%
df.columns
# Out:
# Index(['file_name', 'class_id', 'title', 'instructor', 'location',
#        'course_type', 'cost_gbp', 'learning_objectives', 'provided_materials',
#        'skills_developed', 'description'],
#       dtype='object')
