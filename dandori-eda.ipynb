# %%
import pandas as pd
df = pd.read_pickle("data/courses.pkl")

# %%
df.head()
# Out:
#                                           file_name    class_id  \
# 0  class_001_The_Art_of_Wondrous_Waffle_Weaving.pdf  CLASS_4033
# 1    class_002_Cornish_Pasty_Poetry__Patisserie.pdf  CLASS_0317
# 2               class_003_Mystical_Moss_Mosaics.pdf  CLASS_8879
# 3         class_004_Advanced_Hedgehog_Husbandry.pdf  CLASS_1153
# 4  class_005_Leafy_Quill_and_Ink_Potion_Mastery.pdf  CLASS_9224
#
#                                 title                     instructor  \
# 0  The Art of Wondrous Waffle Weaving                  Chef Waffleby
# 1   Cornish Pasty Poetry & Patisserie             Chef Rhubarb Mince
# 2               Mystical Moss Mosaics  Professor Mossbottom Scottish
# 3         Advanced Hedgehog Husbandry              Mr. Pricklesworth
# 4  Leafy Quill and Ink Potion Mastery         Professor Ivy Fernsnap
#
#     location         course_type  cost_gbp  \
# 0  Harrogate       Culinary Arts      75.0
# 1   Cornwall  Traditional Skills      85.0
# ...

# %%
df.columns
# Out:
# Index(['file_name', 'class_id', 'title', 'instructor', 'location',
#        'course_type', 'cost_gbp', 'learning_objectives', 'provided_materials',
#        'skills_developed', 'description'],
#       dtype='object')

# %%
print(df[df['class_id'] == 'CLASS_2530'])
# Out:
#                                             file_name    class_id  \
# 12  class_013_fantastical_felted_creature_concocti...  CLASS_2530
# 49  class_050_cloud_gazing_and_whimsical_weather_w...  CLASS_2530
#
#                                          title                    instructor  \
# 12     Fantastical Felted Creature Concoctions   Ms. Woolina Fuzzbubble Peak
# 49  Cloud Gazing and Whimsical Weather Writing  Professor Nimbus Cloudsworth
#
#     location  course_type  cost_gbp  \
# 12  District   Fiber Arts      85.0
# 49    Exeter  Mindfulness      65.0
#
#                                   learning_objectives  \
# 12  [Master the basics of needle felting and sculp...
# 49  [Understand the different types of clouds and ...
#
#                                    provided_materials  \
# 12  [Assortment of colorful wool roving, Needle fe...
# 49  [Cloud classification guidebook, Weather obser...
#
#                                      skills_developed  \
# ...

# %%
all_duplicates = df[df.duplicated('class_id', keep=False)]

# %%
all_duplicates
# Out:
#                                              file_name    class_id  \
# 0     class_001_The_Art_of_Wondrous_Waffle_Weaving.pdf  CLASS_4033
# 12   class_013_fantastical_felted_creature_concocti...  CLASS_2530
# 32              class_033_pirate_pastry_plundering.pdf  CLASS_5355
# 48   class_049_the_art_of_edible_poetry_culinary_so...  CLASS_9788
# 49   class_050_cloud_gazing_and_whimsical_weather_w...  CLASS_2530
# 50     class_051_medieval_banter_and_bard_building.pdf  CLASS_5726
# 111  class_112_enchanted_cornish_pasties_a_culinary...  CLASS_2896
# 115  class_116_fantastical_feathered_friend_nesting...  CLASS_9788
# 116  class_117_the_art_of_gourmet_sandwich_sculptur...  CLASS_7904
# 145  class_146_quaint_quillmanship_the_art_of_feath...  CLASS_2896
# 167  class_168_pirate_parrot_persuasion_the_art_of_...  CLASS_7904
# 177  class_178_highland_gnome_gathering_with_gertie...  CLASS_4033
# 192              class_193_unicorn_blanket_weaving.pdf  CLASS_5355
# ...
